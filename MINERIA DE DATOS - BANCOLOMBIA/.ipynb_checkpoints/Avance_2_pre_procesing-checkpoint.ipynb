# %%
# Nativos
import random as rn
import os
import sys
import gc

#calculo
import numpy as np
import pandas as pd
import scipy
from scipy import stats


#grafico
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
from IPython.display import display_html
# %matplotlib inline
sns.set(style="whitegrid")

#Interacciones con output
import warnings
warnings.filterwarnings("ignore")
# warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

gc.collect()

BASE_DIR = os.path.dirname(os.getcwd())
if BASE_DIR not in sys.path: sys.path.append(BASE_DIR)

#from utils import *
#from graphs import *

SEED = 29082013
os.environ['PYTHONHASHSEED']=str(SEED)
np.random.seed(SEED)
rn.seed(SEED)

#subfolder = "data"
# os.listdir(subfolder)

# %% [markdown]
# ## >> Utilitarios

# %%
def null_verificator(data):        
    if data.isnull().any().any():
        view_info = pd.DataFrame(
            pd.concat(
                [data.isnull().any(), 
                 data.isnull().sum(),
                 data.dtypes], 
                axis=1)
        )
        view_info.columns = ['Nulos', 'Cantidad', 'Tipo Col']
        size = data.shape[0]
        view_info['Porcentaje'] = view_info['Cantidad'].apply(
            lambda x: np.round(0 if not x else x*100 / size, 2))
        return view_info
    else:
        return pd.DataFrame.from_dict({'msje':"DATA LIMPIA DE NULOS"}, orient='index')

# %%
def display_horizontal(*args, percent_sep=5):
    html_str=''
    for table in args:
        df = table if isinstance(table, pd.DataFrame) else  pd.DataFrame(table)
        html_str+=df.to_html()
    display_html(
        html_str.replace(
            'table','table style="display:inline;padding-right:{}%"'.format(percent_sep)
        ), 
        raw=True)

# %%
def compare_var_train_test(train, test, col_, **kwargs):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
    
    # cantidad
    sns.displot(train[col_], bins=20, ax=axes[0])
    sns.displot(test[col_], bins=20, ax=axes[0])
    
    #densudad
    sns.kdeplot(train[col_], shade=True, ax=axes[1])
    sns.kdeplot(test[col_], shade=True, ax=axes[1])

# %%
def compare_var_train_test(train, test, col_, **kwargs):
    fig, axes_ = plt.subplots(nrows=1, ncols=4, figsize=(20, 4))
    
    # cantidad
    sns.histplot(train[col_], bins=20, ax=axes_[0], color='b')
    sns.histplot(test[col_], bins=20, ax=axes_[0], color='r')
    
    #densudad
    sns.kdeplot(train[col_], shade=True, ax=axes_[1], color='b')
    sns.kdeplot(test[col_], shade=True, ax=axes_[1], color='r')
    
    ## cajas
    sns.boxplot(y=train[col], ax=axes_[2], color='b')
    sns.boxplot(y=test[col], ax=axes_[3], color='r')

# %% [markdown]
# ## >> Descripción de campos

# %% [raw]
# Empleado --------------- 0=Desempleado, 1=Empleado actualmente
# Tiempo_empleado--------- Número de años que lleva en el empleo actual (si aplica)
# Saldo_cuenta ----------- Saldo en miles de pesos de la cuenta principal con el banco
# Valor_préstamo --------- Valor actual que adeuda en préstamos en el sistema financiero
# Cuentas_otros ---------- Número de cuentas que tiene en otros bancos
# Autocontrol ------------ Mediante una prueba escrita se mide el nivel de autocontrol de la persona, en puntaje de 0 a 100
# Impulsividad ----------- Mediante una prueba escrita se mide el nivel de impulsividad de la persona, en puntaje de 0 a 100
# Confianza -------------- Mediante una prueba escrita se mide el nivel de confianza en sí misma de la persona, en puntaje de 0 a 100
# Incumplimiento --------- 0=Cumplimiento; 1=Incumplimiento

# %% [markdown]
# ## >> Load data

# %%
dicc_load = {
    'engine': 'openpyxl',
    'dtype': {'id': str}
}

# %%
train = pd.read_excel('score_train.xlsx',  **dicc_load)
display(train.head())

test = pd.read_excel('score_test.xlsx',  **dicc_load)
display(test.head())
# Out:
#   id  Empleado  Tiempo_empleo  Saldo_cuenta  Valor_prestamo  Cuentas_otros  Autocontrol  Impulsividad  Confianza  Incumplimiento
# 0  1         0              0       128.133        2895.710              1           45            50         74               0
# 1  2         1              9       919.644        2781.780              0           38            49         58               0
# 2  3         1              4      1521.332        4216.502              1           59            54         37               0
# 3  4         0              0       172.603        1782.369              0           57            58         54               0
# 4  5         1              9       170.364        3918.458              1           49            37         37               0
#    id  Empleado  Tiempo_empleo  Saldo_cuenta  Valor_prestamo  Cuentas_otros  Autocontrol  Impulsividad  Confianza  Incumplimiento
# 0   6         1              9       285.541           0.000              1           50            61         53             NaN
# 1   8         1              3       327.126        3226.726              2           47            65         56             NaN
# 2   9         1              2       287.253        2774.996              1           68            59         63             NaN
# 3  10         0              0       257.328        2757.177              1           59            49         47             NaN
# 4  14         1              1       235.422        1923.073              2           66            45         36             NaN

# %%
train.shape, test.shape
# Out:
# ((63901, 10), (16116, 10))

# %% [markdown]
# ## >> Análisis de nulos

# %%
display_horizontal(
    null_verificator(train), null_verificator(test)
)
# Out:
# <table style="display:inline;padding-right:5%" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>msje</th>
#       <td>DATA LIMPIA DE NULOS</td>
#     </tr>
#   </tbody>
# </table style="display:inline;padding-right:5%"><table style="display:inline;padding-right:5%" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Nulos</th>
#       <th>Cantidad</th>
#       <th>Tipo Col</th>
#       <th>Porcentaje</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>id</th>
#       <td>False</td>
#       <td>0</td>
#       <td>object</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Empleado</th>
#       <td>False</td>
#       <td>0</td>
#       <td>int64</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Tiempo_empleo</th>
#       <td>False</td>
#       <td>0</td>
#       <td>int64</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Saldo_cuenta</th>
#       <td>False</td>
#       <td>0</td>
#       <td>float64</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Valor_prestamo</th>
#       <td>False</td>
#       <td>0</td>
#       <td>float64</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Cuentas_otros</th>
#       <td>False</td>
#       <td>0</td>
#       <td>int64</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Autocontrol</th>
#       <td>False</td>
#       <td>0</td>
#       <td>int64</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Impulsividad</th>
#       <td>False</td>
#       <td>0</td>
#       <td>int64</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Confianza</th>
#       <td>False</td>
#       <td>0</td>
#       <td>int64</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Incumplimiento</th>
#       <td>True</td>
#       <td>16116</td>
#       <td>float64</td>
#       <td>100.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline;padding-right:5%">

# %% [markdown]
# Conclusión: Data sin nulos

# %% [markdown]
# ## >> Revisión de Balanceo

# %%
train['Incumplimiento'].value_counts(dropna=False, normalize=True)
# Out:
# 0    0.858844
# 1    0.141156
# Name: Incumplimiento, dtype: float64

# %% [markdown]
# ## >> Análisis Descriptivo

# %% [markdown]
# #### >>>> Cuantitativos

# %%
display_horizontal(
    train.describe().T, test.describe().T
)
# Out:
# <table style="display:inline;padding-right:5%" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Empleado</th>
#       <td>63901.0</td>
#       <td>0.850738</td>
#       <td>0.356349</td>
#       <td>0.000</td>
#       <td>1.000</td>
#       <td>1.000</td>
#       <td>1.000</td>
#       <td
#       <td>1.023846</td>
#       <td>0.000</td>
#       <td>0.0000</td>
#       <td>1.000</td>
#       <td>2.0000</td>
#       <td>7.000</td>
#     </tr>
#     <tr>
#       <th>Autocontrol</th>
#       <td>16116.0</td>
#       <td>49.983060</td>
#       <td>9.967886</td>
#       <td>8.000</td>
#       <td>43.0000</td>
#       <td>50.000</td>
#       <td>57.0000</td>
#       <td>94.000</td>
#     </tr>
#     <tr>
#       <th>Impulsividad</th>
#       <td>16116.0</td>
#       <td>49.944775</td>
#       <td>10.079814</td>
#       <td>16.000</td>
#       <td>43.0000</td>
#       <td>50.000</td>
#       <td>57.0000</td>
#       <td>87.000</td>
#     </tr>
#     <tr>
#       <th>Confianza</th>
#       <td>16116.0</td>
#       <td>49.946016</td>
#       <td>10.001722</td>
#       <td>12.000</td>
#       <td>43.0000</td>
#       <td>50.000</td>
#       <td>57.0000</td>
#       <td>85.000</td>
#     </tr>
#     <tr>
#       <th>Incumplimiento</th>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline;padding-right:5%">

# %% [markdown]
# ### >> Correcion de valor_prestamo negativos

# %%
train['Valor_prestamo'] = train['Valor_prestamo'].apply(lambda _: 0 if _ < 0 else _)
test['Valor_prestamo'] = test['Valor_prestamo'].apply(lambda _: 0 if _ < 0 else _)

# %%
cols_num = [col for col in train.describe().columns if set(train[col]) != {0, 1}]
print(cols_num)
# Out:
# ['Tiempo_empleo', 'Saldo_cuenta', 'Valor_prestamo', 'Cuentas_otros', 'Autocontrol', 'Impulsividad', 'Confianza']

# %%
for col in cols_num:
    compare_var_train_test(train, test, col)

# %% [markdown]
# #### >>>> Cualitativos

# %%
display_horizontal(
    train.describe(include=[bool, object]).T, test.describe(include=[bool, object]).T
)
# Out:
# <table style="display:inline;padding-right:5%" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>unique</th>
#       <th>top</th>
#       <th>freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>id</th>
#       <td>63901</td>
#       <td>63901</td>
#       <td>62895</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table style="display:inline;padding-right:5%"><table style="display:inline;padding-right:5%" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>unique</th>
#       <th>top</th>
#       <th>freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>id</th>
#       <td>16116</td>
#       <td>16116</td>
#       <td>25734</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table style="display:inline;padding-right:5%">

# %% [markdown]
# ## >> Gráfico QQplot

# %%
from statsmodels.graphics.gofplots import qqplot

for col in cols_num:
    print("/"*50, col)
    fig = qqplot(train[col] , line='s')
    fig2 = qqplot(test[col] , line='s')
    plt.show()
    print("/"*100)
# Out:
# ////////////////////////////////////////////////// Tiempo_empleo
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////// Saldo_cuenta
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////// Valor_prestamo
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////// Cuentas_otros
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////// Autocontrol
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////// Impulsividad
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# ////////////////////////////////////////////////// Confianza
# ////////////////////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# ## >> Pruebas de Normalidad

# %% [raw]
# H0: los datos proceden de una distribución normal
# H1: los datos no proceden de una distribución normal
#
#
# Si p_value <= 0.05 ----> rechazamos la hispotesis nula
# si p_value > 0.05  ----> no existe argumentos suficientes para rechazar la hipótesis

# %%
def test_normalidad(data, col, method='kolmogorov', alpha=0.05, tipo='train'):
    metodos_validos = ['shapiro', 'kolmogorov', 'agostino']
    
    if method not in metodos_validos:
        return 'Ingrese un método válido'
    
    if method == 'shapiro':
        stat, p = stats.shapiro(data[col])
    elif method == 'kolmogorov':
        ks = stats.kstest(data[col], 'norm')
        p = ks.pvalue
        stat = ks.statistic
    elif method == 'agostino':
        stat, p = stats.normaltest(data[col])
    
    if p > alpha:
        msg = 'NORMALIDAD - No hay evidencia para rechzar la hipotesis nula'
    else:
        msg = 'NO GAUSSIANO - Se rechaza la hipotesis nula - NO NORMAL'
    
    return pd.DataFrame({
        'Nombre de variable':  col,
        'Tipo de data': tipo,
        'Tamaño de la muestra': 'train: {}, test: {} '.format(train.shape[0], test.shape[0]),
        'valor del estadístico': stat,
        'p-valor': p,
        'Resultado': msg
    }, index=[0])

# %% [markdown]
# #### >>>> Shapiro

# %%
pd.concat( 
    [test_normalidad(train, col, method='shapiro', tipo='train') for col in cols_num] + [test_normalidad(test, col, method='shapiro', tipo='test') for col in cols_num] , axis=0, ignore_index=True
).sort_values(by=['Nombre de variable'], ascending=False)
# Out:
#    Nombre de variable Tipo de data        Tamaño de la muestra  valor del estadístico       p-valor                                          Resultado
# 2      Valor_prestamo        train  train: 63901, test: 16116                0.868228  0.000000e+00  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 9      Valor_prestamo         test  train: 63901, test: 16116                0.869136  0.000000e+00  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 0       Tiempo_empleo        train  train: 63901, test: 16116                0.898591  0.000000e+00  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 7       Tiempo_empleo         test  train: 63901, test: 16116                0.893868  0.000000e+00  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 1        Saldo_cuenta        train  train: 63901, test: 16116                0.131857  0.000000e+00  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 8        Saldo_cuenta         test  train: 63901, test: 16116                0.100939  0.000000e+00  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 5        Impulsividad        train  train: 63901, test: 16116                0.999322  2.216399e-14  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 12       Impulsividad         test  train: 63901, test: 16116                0.998960  1.379161e-08  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 3       Cuentas_otros        train  train: 63901, test: 16116                0.833501  0.000000e+00  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 10      Cuentas_otros         test  train: 63901, test: 16116                0.830989  0.000000e+00  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 6           Confianza        train  train: 63901, test: 16116                0.999197  5.304466e-16  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 13          Confianza         test  train: 63901, test: 16116                0.999064  6.798384e-08  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 4         Autocontrol        train  train: 63901, test: 16116                0.999182  3.439726e-16  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 11        Autocontrol         test  train: 63901, test: 16116                0.999046  5.103515e-08  NO GAUSSIANO - Se rechaza la hipotesis nula - ...

# %% [markdown]
# #### >>>>  Kolmogorov Smirnov

# %%
pd.concat( 
    [test_normalidad(train, col, method='kolmogorov', tipo='train') for col in cols_num] + [test_normalidad(test, col, method='kolmogorov', tipo='test') for col in cols_num] , axis=0, ignore_index=True
).sort_values(by=['Nombre de variable'], ascending=False)
# Out:
#    Nombre de variable Tipo de data        Tamaño de la muestra  valor del estadístico  p-valor                                          Resultado
# 2      Valor_prestamo        train  train: 63901, test: 16116                0.899188      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 9      Valor_prestamo         test  train: 63901, test: 16116                0.898858      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 0       Tiempo_empleo        train  train: 63901, test: 16116                0.751651      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 7       Tiempo_empleo         test  train: 63901, test: 16116                0.750208      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 1        Saldo_cuenta        train  train: 63901, test: 16116                0.974890      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 8        Saldo_cuenta         test  train: 63901, test: 16116                0.975354      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 5        Impulsividad        train  train: 63901, test: 16116                1.000000      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 12       Impulsividad         test  train: 63901, test: 16116                1.000000      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 3       Cuentas_otros        train  train: 63901, test: 16116                0.500000      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 10      Cuentas_otros         test  train: 63901, test: 16116                0.500000      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 6           Confianza        train  train: 63901, test: 16116                1.000000      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 13          Confianza         test  train: 63901, test: 16116                1.000000      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 4         Autocontrol        train  train: 63901, test: 16116                1.000000      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 11        Autocontrol         test  train: 63901, test: 16116                1.000000      0.0  NO GAUSSIANO - Se rechaza la hipotesis nula - ...

# %% [markdown]
# #### >>>> Agostino

# %%
pd.concat( 
    [test_normalidad(train, col, method='agostino', tipo='train') for col in cols_num] + [test_normalidad(test, col, method='agostino', tipo='test') for col in cols_num] , axis=0, ignore_index=True
).sort_values(by=['Nombre de variable'], ascending=False)
# Out:
#    Nombre de variable Tipo de data        Tamaño de la muestra  valor del estadístico   p-valor                                          Resultado
# 2      Valor_prestamo        train  train: 63901, test: 16116            11516.150657  0.000000  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 9      Valor_prestamo         test  train: 63901, test: 16116             2879.088899  0.000000  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 0       Tiempo_empleo        train  train: 63901, test: 16116            14263.131960  0.000000  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 7       Tiempo_empleo         test  train: 63901, test: 16116             3991.001669  0.000000  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 1        Saldo_cuenta        train  train: 63901, test: 16116           172665.053320  0.000000  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 8        Saldo_cuenta         test  train: 63901, test: 16116            44020.376613  0.000000  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 5        Impulsividad        train  train: 63901, test: 16116                1.173941  0.556009  NORMALIDAD - No hay evidencia para rechzar la ...
# 12       Impulsividad         test  train: 63901, test: 16116                5.529088  0.063005  NORMALIDAD - No hay evidencia para rechzar la ...
# 3       Cuentas_otros        train  train: 63901, test: 16116             8751.021816  0.000000  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 10      Cuentas_otros         test  train: 63901, test: 16116             2586.984968  0.000000  NO GAUSSIANO - Se rechaza la hipotesis nula - ...
# 6           Confianza        train  train: 63901, test: 16116                0.639843  0.726206  NORMALIDAD - No hay evidencia para rechzar la ...
# 13          Confianza         test  train: 63901, test: 16116                0.863631  0.649329  NORMALIDAD - No hay evidencia para rechzar la ...
# 4         Autocontrol        train  train: 63901, test: 16116                0.528009  0.767970  NORMALIDAD - No hay evidencia para rechzar la ...
# 11        Autocontrol         test  train: 63901, test: 16116                4.089290  0.129426  NORMALIDAD - No hay evidencia para rechzar la ...

# %% [markdown]
# ## >> Pruebas de Homocedasticidad

# %% [raw]
# H0: Todas las varianzas de una población k son iguales (homocedasticidad)
# H1: Al menos dos son diferentes (heterocedasticidad)
#
# Si p_value <= 0.05 ----> rechazamos la hispotesis nula
# si p_value > 0.05  ----> no existe argumentos suficientes para rechazar la hipótesis

# %%
def test_homocedasticidad(train, test, col, method='bartlett', alpha=0.05):
    metodos_validos = ['levene', 'bartlett', 'fligner']
    
    if method not in metodos_validos:
        return 'Ingrese un método válido'
    
    if method == 'levene':
        prueba = stats.levene(train[col], test[col], center='median')
    elif method == 'bartlett':
        prueba = stats.bartlett(train[col], test[col])
    elif method == 'fligner':
        prueba = stats.fligner(train[col], test[col], center='median')

    p = prueba.pvalue
    stat = prueba.statistic
    
    if p > alpha:
        msg = 'HOMOCEDASTICIDAD - No hay evidencia para rechzar la hipotesis nula'
    else:
        msg = 'HETEROCEDASTICIDAD - Se rechaza la hipotesis nula - NO NORMAL'
    
    return pd.DataFrame({
        'Nombre de variable':  col,
        'Tamaño de la muestra': 'train: {}, test: {} '.format(train.shape[0], test.shape[0]),
        'valor del estadístico': stat,
        'p-valor': p,
        'Resultado': msg
    }, index=[0])

# %% [markdown]
# #### >>>> Barlett

# %%
pd.concat( 
    [test_homocedasticidad(train, test, col, method='bartlett') for col in cols_num], axis=0, ignore_index=True
)
# Out:
#   Nombre de variable        Tamaño de la muestra  valor del estadístico        p-valor                                          Resultado
# 0      Tiempo_empleo  train: 63901, test: 16116                1.612310   2.041674e-01  HOMOCEDASTICIDAD - No hay evidencia para rechz...
# 1       Saldo_cuenta  train: 63901, test: 16116             1082.685713  1.914578e-237  HETEROCEDASTICIDAD - Se rechaza la hipotesis n...
# 2     Valor_prestamo  train: 63901, test: 16116                0.083277   7.729043e-01  HOMOCEDASTICIDAD - No hay evidencia para rechz...
# 3      Cuentas_otros  train: 63901, test: 16116               13.974997   1.852579e-04  HETEROCEDASTICIDAD - Se rechaza la hipotesis n...
# 4        Autocontrol  train: 63901, test: 16116                2.544819   1.106566e-01  HOMOCEDASTICIDAD - No hay evidencia para rechz...
# 5       Impulsividad  train: 63901, test: 16116                0.724656   3.946208e-01  HOMOCEDASTICIDAD - No hay evidencia para rechz...
# 6          Confianza  train: 63901, test: 16116                0.019911   8.877864e-01  HOMOCEDASTICIDAD - No hay evidencia para rechz...

# %% [markdown]
# #### >>>> Levene

# %%
pd.concat( 
    [test_homocedasticidad(train, test, col, method='levene') for col in cols_num], axis=0, ignore_index=True
)
# Out:
#   Nombre de variable        Tamaño de la muestra  valor del estadístico   p-valor                                          Resultado
# 0      Tiempo_empleo  train: 63901, test: 16116                0.234873  0.627935  HOMOCEDASTICIDAD - No hay evidencia para rechz...
# 1       Saldo_cuenta  train: 63901, test: 16116                0.327388  0.567203  HOMOCEDASTICIDAD - No hay evidencia para rechz...
# 2     Valor_prestamo  train: 63901, test: 16116                0.002325  0.961541  HOMOCEDASTICIDAD - No hay evidencia para rechz...
# 3      Cuentas_otros  train: 63901, test: 16116                2.197305  0.138256  HOMOCEDASTICIDAD - No hay evidencia para rechz...
# 4        Autocontrol  train: 63901, test: 16116                4.549158  0.032938  HETEROCEDASTICIDAD - Se rechaza la hipotesis n...
# 5       Impulsividad  train: 63901, test: 16116                1.623600  0.202594  HOMOCEDASTICIDAD - No hay evidencia para rechz...
# 6          Confianza  train: 63901, test: 16116                0.094557  0.758463  HOMOCEDASTICIDAD - No hay evidencia para rechz...

# %% [markdown]
# #### >>>> Fligner

# %%
pd.concat( 
    [test_homocedasticidad(train, test, col, method='fligner') for col in cols_num], axis=0, ignore_index=True
)
# Out:
#   Nombre de variable        Tamaño de la muestra  valor del estadístico       p-valor                                          Resultado
# 0      Tiempo_empleo  train: 63901, test: 16116                0.151197  6.973942e-01  HOMOCEDASTICIDAD - No hay evidencia para rechz...
# 1       Saldo_cuenta  train: 63901, test: 16116               12.787828  3.488820e-04  HETEROCEDASTICIDAD - Se rechaza la hipotesis n...
# 2     Valor_prestamo  train: 63901, test: 16116               47.765487  4.803746e-12  HETEROCEDASTICIDAD - Se rechaza la hipotesis n...
# 3      Cuentas_otros  train: 63901, test: 16116                2.266147  1.322283e-01  HOMOCEDASTICIDAD - No hay evidencia para rechz...
# 4        Autocontrol  train: 63901, test: 16116                4.565989  3.261284e-02  HETEROCEDASTICIDAD - Se rechaza la hipotesis n...
# 5       Impulsividad  train: 63901, test: 16116                1.614713  2.038306e-01  HOMOCEDASTICIDAD - No hay evidencia para rechz...
# 6          Confianza  train: 63901, test: 16116                0.089894  7.643121e-01  HOMOCEDASTICIDAD - No hay evidencia para rechz...

# %% [markdown]
# ## >> Analisis de Correlación

# %%
train.corr(method='spearman').style.background_gradient(
    cmap='coolwarm', axis=None
).set_precision(3)
# Out:
# <style  type="text/css" >
# #T_cf3a4_row0_col0,#T_cf3a4_row1_col1,#T_cf3a4_row2_col2,#T_cf3a4_row3_col3,#T_cf3a4_row4_col4,#T_cf3a4_row5_col5,#T_cf3a4_row6_col6,#T_cf3a4_row7_col7,#T_cf3a4_row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_cf3a4_row0_col1,#T_cf3a4_row1_col0{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_cf3a4_row0_col2,#T_cf3a4_row0_col7,#T_cf3a4_row0_col8,#T_cf3a4_row1_col2,#T_cf3a4_row1_col3,#T_cf3a4_row1_col4,#T_cf3a4_row1_col8,#T_cf3a4_row2_col0,#T_cf3a4_row2_col1,#T_cf3a4_row2_col4,#T_cf3a4_row2_col6,#T_cf3a4_row3_col1,#T_cf3a4_row3_col7,#T_cf3a4_row4_col1,#T_cf3a4_row4_col2,#T_cf3a4_row4_col5,#T_cf3a4_row4_col7,#T_cf3a4_row5_col4,#T_cf3a4_row5_col6,#T_cf3a4_row6_col2,#T_cf3a4_row6_col5,#T_cf3a4_row7_col0,#T_cf3a4_row7_col3,#T_cf3a4_row7_col4,#T_cf3a4_row8_col0,#T_cf3a4_row8_col1{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_cf3a4_row0_col3,#T_cf3a4_row0_col6,#T_cf3a4_row1_col6,#T_cf3a4_row2_col5,#T_cf3a4_row2_col7,#T_cf3a4_row2_col8,#T_cf3a4_row3_col0,#T_cf3a4_row3_col4,#T_cf3a4_row3_col6,#T_cf3a4_row3_col8,#T_cf3a4_row4_col3,#T_cf3a4_row5_col2,#T_cf3a4_row5_col8,#T_cf3a4_row6_col0,#T_cf3a4_row6_col1,#T_cf3a4_row6_col3,#T_cf3a4_row6_col7,#T_cf3a4_row6_col8,#T_cf3a4_row7_col2,#T_cf3a4_row7_col6,#T_cf3a4_row7_col8,#T_cf3a4_row8_col2,#T_cf3a4_row8_col3,#T_cf3a4_row8_col5,#T_cf3a4_row8_col6,#T_cf3a4_row8_col7{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_cf3a4_row0_col4,#T_cf3a4_row0_col5,#T_cf3a4_row1_col5,#T_cf3a4_row1_col7,#T_cf3a4_row2_col3,#T_cf3a4_row3_col2,#T_cf3a4_row4_col0,#T_cf3a4_row4_col6,#T_cf3a4_row4_col8,#T_cf3a4_row5_col0,#T_cf3a4_row5_col1,#T_cf3a4_row5_col7,#T_cf3a4_row6_col4,#T_cf3a4_row7_col1,#T_cf3a4_row7_col5,#T_cf3a4_row8_col4{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_cf3a4_row3_col5,#T_cf3a4_row5_col3{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }</style><table id="T_cf3a4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Empleado</th>        <th class="col_heading level0 col1" >Tiempo_empleo</th>        <th class="col_heading level0 col2" >Saldo_cuenta</th>        <th class="col_heading level0 col3" >Valor_prestamo</th>        <th class="col_heading level0 col4" >Cuentas_otros</th>        <th class="col_heading level0 col5" >Autocontrol</th>        <th class="col_heading level0 col6" >Impulsividad</th>        <th class="col_heading level0 col7" >Confianza</th>        <th class="col_heading level0 col8" >Incumplimiento</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cf3a4_level0_row0" class="row_heading level0 row0" >Empleado</th>
#                         <td id="T_cf3a4_row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T
td>
#             </tr>
#             <tr>
#                         <th id="T_cf3a4_level0_row4" class="row_heading level0 row4" >Cuentas_otros</th>
#                         <td id="T_cf3a4_row4_col0" class="data row4 col0" >0.003</td>
#                         <td id="T_cf3a4_row4_col1" class="data row4 col1" >-0.001</td>
#                         <td id="T_cf3a4_row4_col2" class="data row4 col2" >0.001</td>
#                         <td id="T_cf3a4_row4_col3" class="data row4 col3" >-0.002</td>
#                         <td id="T_cf3a4_row4_col4" class="data row4 col4" >1.000</td>
#                         <td id="T_cf3a4_row4_col5" class="data row4 col5" >-0.000</td>
#                         <td id="T_cf3a4_row4_col6" class="data row4 col6" >0.003</td>
#                         <td id="T_cf3a4_row4_col7" class="data row4 col7" >0.002</td>
#                         <td id="T_cf3a4_row4_col8" class="data row4 col8" >0.005</td>
#             </tr>
#             <tr>
#                         <th id="T_cf3a4_level0_row5" class="row_heading level0 row5" >Autocontrol</th>
#                         <td id="T_cf3a4_row5_col0" class="data row5 col0" >0.006</td>
#                         <td id="T_cf3a4_row5_col1" class="data row5 col1" >0.003</td>
#                         <td id="T_cf3a4_row5_col2" class="data row5 col2" >-0.002</td>
#                         <td id="T_cf3a4_row5_col3" class="data row5 col3" >0.007</td>
#                         <td id="T_cf3a4_row5_col4" class="data row5 col4" >-0.000</td>
#                         <td id="T_cf3a4_row5_col5" class="data row5 col5" >1.000</td>
#                         <td id="T_cf3a4_row5_col6" class="data row5 col6" >

# %%
test.corr(method='spearman').style.background_gradient(
    cmap='coolwarm', axis=None
).set_precision(3)
# Out:
# <style  type="text/css" >
# #T_ebee6_row0_col0,#T_ebee6_row1_col1,#T_ebee6_row2_col2,#T_ebee6_row3_col3,#T_ebee6_row4_col4,#T_ebee6_row5_col5,#T_ebee6_row6_col6,#T_ebee6_row7_col7{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_ebee6_row0_col1,#T_ebee6_row1_col0{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_ebee6_row0_col2,#T_ebee6_row0_col5,#T_ebee6_row0_col6,#T_ebee6_row1_col3,#T_ebee6_row1_col5,#T_ebee6_row1_col6,#T_ebee6_row2_col0,#T_ebee6_row3_col1,#T_ebee6_row3_col5,#T_ebee6_row3_col6,#T_ebee6_row5_col0,#T_ebee6_row5_col1,#T_ebee6_row5_col3,#T_ebee6_row6_col0,#T_ebee6_row6_col1,#T_ebee6_row6_col3{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_ebee6_row0_col3,#T_ebee6_row1_col4,#T_ebee6_row3_col0,#T_ebee6_row4_col1{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_ebee6_row0_col4,#T_ebee6_row1_col2,#T_ebee6_row2_col1,#T_ebee6_row4_col0,#T_ebee6_row4_col6,#T_ebee6_row6_col4{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_ebee6_row0_col7,#T_ebee6_row1_col7,#T_ebee6_row2_col4,#T_ebee6_row2_col6,#T_ebee6_row2_col7,#T_ebee6_row3_col4,#T_ebee6_row4_col2,#T_ebee6_row4_col3,#T_ebee6_row5_col6,#T_ebee6_row6_col2,#T_ebee6_row6_col5,#T_ebee6_row7_col0,#T_ebee6_row7_col1,#T_ebee6_row7_col2{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_ebee6_row0_col8,#T_ebee6_row1_col8,#T_ebee6_row2_col8,#T_ebee6_row3_col8,#T_ebee6_row4_col8,#T_ebee6_row5_col8,#T_ebee6_row6_col8,#T_ebee6_row7_col8,#T_ebee6_row8_col0,#T_ebee6_row8_col1,#T_ebee6_row8_col2,#T_ebee6_row8_col3,#T_ebee6_row8_col4,#T_ebee6_row8_col5,#T_ebee6_row8_col6,#T_ebee6_row8_col7,#T_ebee6_row8_col8{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_ebee6_row2_col3,#T_ebee6_row3_col2,#T_ebee6_row4_col5,#T_ebee6_row5_col4,#T_ebee6_row5_col7,#T_ebee6_row7_col5{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_ebee6_row2_col5,#T_ebee6_row5_col2{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_ebee6_row3_col7,#T_ebee6_row4_col7,#T_ebee6_row6_col7,#T_ebee6_row7_col3,#T_ebee6_row7_col4,#T_ebee6_row7_col6{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_ebee6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Empleado</th>        <th class="col_heading level0 col1" >Tiempo_empleo</th>        <th class="col_heading level0 col2" >Saldo_cuenta</th>        <th class="col_heading level0 col3" >Valor_prestamo</th>        <th class="col_heading level0 col4" >Cuentas_otros</th>        <th class="col_heading level0 col5" >Autocontrol</th>        <th class="col_heading level0 col6" >Impulsividad</th>        <th class="col_heading level0 col7" >Confianza</th>        <th class="col_heading level0 col8" >Incumplimiento</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ebee6_level0_row0" class="row_heading level0 row0" >Empleado</th>
#                         <td id="T_ebee6_row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_ebee6_row0_col1" class="data row0 col1" >0.612</td>
#                         <td id="T_ebee6_row0_col2" class="data row0 col2" >0.000</td>
#                         <td id="T_ebee6_row0_col3" class="data row0 col3" >0.006</td>
#                         <td id="T_ebee6_row0_col4" class="data row0 col4" >0.011</td>
#                         <td id="T_ebee6_row0_col5" class="data row0 col5" >0.001</td>
#                         <td id="T_ebee6_row0_col6" class="data row0 col6" >-0.001</td>
#                         <td id="T_ebee6_row0_col7" class="data row0 col7" >0.013</td>
#                         <td id="T_ebee6_row0_col8" class="data row0 col8" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_ebee6_level0_row1" class="row_heading level0 row1" >Tiempo_empleo</th>
#                         <td id="T_ebee6_row1_col0" class="data row1 col0" >0.612</td>
#                         <td id="T_ebee6_row1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_ebee6_row1_col2" class="data row1 col2" >0.010</td>
#                         <td id="T_ebee6_row1_col3" class="data row1 col3" >-0.001</td>
#                         <td id="T_ebee6_row1_col4" class="data row1 col4" >0.008</td>
#                         <td id="T_ebee6_row1_col5" class="data row1 col5" >-0.000</td>
#                         <td id="T_ebee6_row1_col6" class="data row1 col6" >-0.001</td>
#                         <td id="T_ebee6_row1_col7" class="data row1 col7" >0.017</td>
#                         <td id="T_ebee6_row1_col8" class="data row1 col8" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_ebee6_level0_row2" class="row_heading level0 row2" >Saldo_cuenta</th>
#                         <td id="T_ebee6_row2_col0" class="data row2 col0" >0.000</td>
#                         <td id="T_ebee6_row2_col1" class="data row2 col1" >0.010</td>
#                         <td id="T_ebee6_row2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_ebee6_row2_col3" class="data row2 col3" >0.003</td>
#                         <td id="T_ebee6_row2_col4" class="data row2 col4" >0.014</td>
#                         <td id="T_ebee6_row2_col5" class="data row2 col5" >-0.006</td>
#                         <td id="T_ebee6_row2_col6" class="data row2 col6" >0.013</td>
#                         <td id="T_ebee6_row2_col7" class="data row2 col7" >0.014</td>
#                         <td id="T_ebee6_row2_col8" class="data row2 col8" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_ebee6_level0_row3" class="row_heading level0 row3" >Valor_prestamo</th>
#                         <td id="T_ebee6_row3_col0" class="data row3 col0" >0.006</td>
#                         <td id="T_ebee6_row3_col1" class="data row3 col1" >-0.001</td>
#                         <td id="T_ebee6_row3_col2" class="data row3 col2" >0.003</td>
#                         <td id="T_ebee6_row3_col3" class="data row3 col3" >1.000</td>
#                         <td id="T_ebee6_row3_col4" class="data row3 col4" >0.014</td>
#                         <td id="T_ebee6_row3_col5" class="data row3 col5" >0.000</td>
#                         <td id="T_ebee6_row3_col6" class="data row3 col6" >-0.002</td>
#                         <td id="T_ebee6_row3_col7" class="data row3 col7" >-0.010</td>
#                         <td id="T_ebee6_row3_col8" class="data row3 col8" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_ebee6_level0_row4" class="row_heading level0 row4" >Cuentas_otros</th>
#                         <td id="T_ebee6_row4_col0" class="data row4 col0" >0.011</td>
#                         <td id="T_ebee6_row4_col1" class="data row4 col1" >0.008</td>
#                         <td id="T_ebee6_row4_col2" class="data row4 col2" >0.014</td>
#                         <td id="T_ebee6_row4_col3" class="data row4 col3" >0.014</td>
#                         <td id="T_ebee6_row4_col4" class="data row4 col4" >1.000</td>
#                         <td id="T_ebee6_row4_col5" class="data row4 col5" >0.005</td>
#                         <td id="T_ebee6_row4_col6" class="data row4 col6" >0.013</td>
#                         <td id="T_ebee6_row4_col7" class="data row4 col7" >-0.008</td>
#                         <td id="T_ebee6_row4_col8" class="data row4 col8" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_ebee6_level0_row5" class="row_heading level0 row5" >Autocontrol</th>
#                         <td id="T_ebee6_row5_col0" class="data row5 col0" >0.001</td>
#                         <td id="T_ebee6_row5_col1" class="data row5 col1" >-0.000</td>
#                         <td id="T_ebee6_row5_col2" class="data row5 col2" >-0.006</td>
#                         <td id="

# %% [markdown]
# ## >> Inspección de Gráicos Bivariado

# %%
def graph_numeric(data, col_init, col_out, **kwargs):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 4))
    
    sns.lineplot(x=col_init, y=col_out, data=data, ax=axes[0])
    sns.violinplot(x=col_init, y=col_out, data=data, ax=axes[1], orient='h')
    
    legend_list = []
    
    for opt in data[col_out].unique():
        sns.kdeplot(data[data[col_out] == opt][col_init], ax=axes[2], shade=True)
        legend_list.append(opt)
    plt.legend(legend_list)

# %%
def graph_categoryc(data, col_init, col_out, **kwargs):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 5))
    
    cp = sns.countplot(x=col_init, hue=col_out, data=data, ax=axes[0])
    plt.setp(cp.get_xticklabels(), rotation=90)
    
    cross = pd.crosstab(data[col_out], data[col_init])
    sum_total = sum([cross[col].sum() for col in cross.columns])
    sns.heatmap(
        cross/sum_total, 
        annot=True, ax=axes[1], center=0, cmap="YlGnBu", fmt='.0%'
    )
    bp = sns.barplot(
        x=col_init, y=col_out, data=data, ax=axes[2]
    )
    
    plt.setp(bp.get_xticklabels(), rotation=90)

# %%
graph_numeric(train, 'Tiempo_empleo', 'Incumplimiento')

# %%
graph_numeric(train[train['Saldo_cuenta'] < 1000], 'Saldo_cuenta', 'Incumplimiento')

# %%
graph_numeric(train, 'Valor_prestamo', 'Incumplimiento')

# %%
graph_numeric(train, 'Cuentas_otros', 'Incumplimiento')

# %%
graph_numeric(train, 'Autocontrol', 'Incumplimiento')

# %%
graph_numeric(train, 'Impulsividad', 'Incumplimiento')

# %%
graph_numeric(train, 'Confianza', 'Incumplimiento')

# %%
import itertools

def div_simple(x, y):
    if x == 0 or y == 0:
        return 0
    
    return x / y

for a, b in list(itertools.combinations(['Cuentas_otros', 'Valor_prestamo', 'Saldo_cuenta', 'Tiempo_empleo'] + ['Autocontrol', 'Impulsividad', 'Confianza'], 2)):
    new_col = '{}_x_{}'.format(a, b).lower()
    
    train[new_col] = train[[a, b]].apply(lambda _: _[0]*_[1], axis=1)
    test[new_col] = test[[a, b]].apply(lambda _: _[0]*_[1], axis=1)
    
    if 'cuentas_otros' not in new_col:
        other_nwe = new_col  + '_entre_cuentas_otros'
        train[other_nwe] = train[[new_col, 'Cuentas_otros']].apply(lambda _: div_simple(_[0], _[1]), axis=1)
        test[other_nwe] = test[[new_col, 'Cuentas_otros']].apply(lambda _: div_simple(_[0], _[1]), axis=1)
        
    if 'tiempo_empleo' not in new_col:
        other_nwe = new_col  + '_entre_tiempo_empleo'
        train[other_nwe] = train[[new_col, 'Tiempo_empleo']].apply(lambda _: div_simple(_[0], _[1]), axis=1)
        test[other_nwe] = test[[new_col, 'Tiempo_empleo']].apply(lambda _: div_simple(_[0], _[1]), axis=1)
        
    graph_numeric(train, new_col, 'Incumplimiento')

# %%
view_graph = False

# %%
train.describe().T
# Out:
#                                                       count          mean           std      min           25%            50%           75%           max
# Empleado                                            63901.0  8.507379e-01  3.563495e-01    0.000      1.000000       1.000000  1.000000e+00  1.000000e+00
# Tiempo_empleo                                       63901.0  5.097354e+00  4.448149e+00    0.000      2.000000       4.000000  7.000000e+00  4.800000e+01
# Saldo_cuenta                                        63901.0  1.074294e+03  5.772013e+03    0.046     38.761000     147.834000  5.749880e+02  5.485922e+05
# Valor_prestamo                                      63901.0  2.475227e+03  1.007258e+03    0.000   2169.124000    2668.597000  3.110260e+03  5.307619e+03
# Cuentas_otros                                       63901.0  1.002942e+00  1.000371e+00    0.000      0.000000       1.000000  2.000000e+00  7.000000e+00
# Autocontrol                                         63901.0  4.992211e+01  1.006770e+01    8.000     43.000000      50.000000  5.700000e+01  9.300000e+01
# Impulsividad                                        63901.0  4.996579e+01  1.002653e+01   12.000     43.000000      50.000000  5.700000e+01  9.200000e+01
# Confianza                                           63901.0  4.998106e+01  1.001052e+01    8.000     43.000000      50.000000  5.700000e+01  9.400000e+01
# Incumplimiento                                      63901.0  1.411559e-01  3.481850e-01    0.000      0.000000       0.000000  0.000000e+00  1.000000e+00
# cuentas_otros_x_valor_prestamo                      63901.0  2.480853e+03  2.858950e+03    0.000      0.000000    2255.583000  3.636446e+03  2.316083e+04
# cuentas_otros_x_valor_prestamo_entre_tiempo_empleo  63901.0  5.863039e+02  1.151592e+03    0.000      0.000000       0.000000  7.226725e+02  2.089466e+04
# cuentas_otros_x_saldo_cuenta                        63901.0  1.078320e+03  7.352751e+03    0.000      0.000000      40.763000  3.628730e+02  5.485922e+05
# cuentas_otros_x_saldo_cuenta_entre_tiempo_empleo    63901.0  2.469625e+02  2.173148e+03    0.000      0.000000       1.654750  5.248871e+01  1.726851e+05
# autocontrol_x_confianza                             63901.0  2.495619e+03  7.175689e+02  228.000   1980.000000    2448.000000  2.952000e+03  6.083000e+03
# autocontrol_x_confianza_entre_cuentas_otros         63901.0  1.217539e+03  1.179342e+03    0.000      0.000000    1063.333333  2.150000e+03  6.083000e+03
# autocontrol_x_confianza_entre_tiempo_empleo         63901.0  5.911363e+02  6.651844e+02    0.000    194.727273     396.333333  7.410000e+02  5.673000e+03
# impulsividad_x_confianza                            63901.0  2.496876e+03  7.136603e+02  340.000   1989.000000    2448.000000  2.950000e+03  6.075000e+03
# impulsividad_x_confianza_entre_cuentas_otros        63901.0  1.217395e+03  1.177426e+03    0.000      0.000000    1071.000000  2.145000e+03  6.003000e+03
# impulsividad_x_confianza_entre_tiempo_empleo        63901.0  5.910051e+02  6.643907e+02    0.000    194.400000     396.500000  7.410000e+02  5.698000e+03

# %% [markdown]
# ## Nuevamente correlacion

# %%
matriz_corr = train.corr(method='spearman')

matriz_corr.style.background_gradient(
    cmap='coolwarm', axis=None
).set_precision(5)
# Out:
# <style  type="text/css" >
# #T_083db_row0_col0,#T_083db_row1_col1,#T_083db_row2_col2,#T_083db_row3_col3,#T_083db_row4_col4,#T_083db_row5_col5,#T_083db_row6_col6,#T_083db_row7_col7,#T_083db_row8_col8,#T_083db_row9_col9,#T_083db_row10_col10,#T_083db_row11_col11,#T_083db_row12_col12,#T_083db_row13_col13,#T_083db_row14_col14,#T_083db_row15_col15,#T_083db_row16_col16,#T_083db_row17_col17,#T_083db_row18_col18,#T_083db_row19_col19,#T_083db_row20_col20,#T_083db_row21_col21,#T_083db_row22_col22,#T_083db_row23_col23,#T_083db_row24_col24,#T_083db_row25_col25,#T_083db_row26_col26,#T_083db_row27_col27,#T_083db_row28_col28,#T_083db_row29_col29,#T_083db_row30_col30,#T_083db_row31_col31,#T_083db_row32_col32,#T_083db_row33_col33,#T_083db_row34_col34,#T_083db_row35_col35,#T_083db_row36_col36,#T_083db_row37_col37,#T_083db_row37_col40,#T_083db_row37_col43,#T_083db_row38_col38,#T_083db_row39_col39,#T_083db_row40_col37,#T_083db_row40_col40,#T_083db_row40_col43,#T_083db_row41_col41,#T_083db_row42_col42,#T_083db_row43_col37,#T_083db_row43_col40,#T_083db_row43_col43,#T_083db_row44_col44,#T_083db_row45_col45,#T_083db_row46_col46,#T_083db_row47_col47,#T_083db_row48_col48,#T_083db_row49_col49,#T_083db_row50_col50,#T_083db_row51_col51,#T_083db_row52_col52,#T_083db_row53_col53,#T_083db_row54_col54,#T_083db_row55_col55,#T_083db_row56_col56,#T_083db_row57_col57,#T_083db_row58_col58,#T_083db_row59_col59{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T
row5_col48,#T_083db_row5_col49,#T_083db_row5_col50,#T_083db_row6_col2,#T_083db_row6_col4,#T_083db_row6_col5,#T_083db_row6_col9,#T_083db_row6_col10,#T_083db_row6_col11,#T_083db_row6_col12,#T_083db_row6_col13,#T_083db_row6_col14,#T_083db_row6_col15,#T_083db_row6_col18,#T_083db_row6_col19,#T_083db_row6_col20,#T_083db_row6_col21,#T_083db_row6_col24,#T_083db_row6_col26,#T_083db_row6_col32,#T_083db_row6_col35,#T_083db_row6_col36,#T_083db_row6_col37,#T_083db_row6_col38,#T_083db_row6_col42,#T_083db_row6_col43,#T_083db_row6_col44,#T_083db_row6_col46,#T_083db_row6_col55,#T_083db_row6_col56,#T_083db_row7_col0,#T_083db_row7_col1,#T_083db_row7_col3,#T_083db_row7_col4,#T_083db_row7_col9,#T_083db_row7_col11,#T_083db_row7_col14,#T_083db_row7_col16,#T_083db_row7_col21,#T_083db_row7_col23,#T_083db_row7_col25,#T_083db_row7_col26,#T_083db_row7_col29,#T_083db_row7_col37,#T_083db_row7_col40,#T_083db_row7_col45,#T_083db_row7_col47,#T_083db_row7_col51,#T_083db_row7_col53,#T_083db_row8_col0,#T_083db_row8_col1,#T_083db_row8_col10,#T_083db_row8_col11,#T_083db_row8_col12,#T_083db_row8_col17,#T_083db_row8_col21,#T_083db_row8_col23,#T_083db_row8_col24,#T_083db_row8_col26,#T_083db_row8_col27,#T_083db_row8_col29,#T_083db_row8_col30,#T_083db_row8_col32,#T_083db_row8_col33,#T_083db_row8_col34,#T_083db_row8_col35,#T_083db_row8_col37,#T_083db_row8_col40,#T_083db_row8_col43,#T_083db_row8_col45,#T_083db_row8_col47,#T_083db_row8_col48,#T_083db_row8_col49,#T_083db_row8_col52,#T_083db_row8_col53,#T_083db_row8_col55,#T_083db_row8_col56,#T_083db_row8_col58,#T_083db_row8_col59,#T_083db_row9_col0,#T_083db_row9_col1,#T_083db_row9_col6,#T_083db_row9_col7,#T_083db_row9_col34,#T_083db_row9_col38,#T_083db_row9_col41,#T_083db_row9_col44,#T_083db_row9 ...

# %%
pd.DataFrame(matriz_corr['Incumplimiento'].abs().sort_values(ascending=False)).style.background_gradient(
    cmap='coolwarm', axis=None
).set_precision(5)
# Out:
# <style  type="text/css" >
# #T_dbc88_row0_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_dbc88_row1_col0,#T_dbc88_row2_col0,#T_dbc88_row3_col0,#T_dbc88_row4_col0,#T_dbc88_row5_col0,#T_dbc88_row6_col0,#T_dbc88_row7_col0,#T_dbc88_row8_col0,#T_dbc88_row9_col0,#T_dbc88_row10_col0,#T_dbc88_row11_col0,#T_dbc88_row12_col0,#T_dbc88_row13_col0,#T_dbc88_row14_col0,#T_dbc88_row15_col0,#T_dbc88_row16_col0,#T_dbc88_row17_col0,#T_dbc88_row18_col0,#T_dbc88_row19_col0,#T_dbc88_row20_col0,#T_dbc88_row21_col0,#T_dbc88_row22_col0,#T_dbc88_row23_col0,#T_dbc88_row24_col0,#T_dbc88_row25_col0,#T_dbc88_row26_col0,#T_dbc88_row27_col0{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_dbc88_row28_col0,#T_dbc88_row29_col0,#T_dbc88_row30_col0,#T_dbc88_row31_col0,#T_dbc88_row32_col0,#T_dbc88_row33_col0,#T_dbc88_row34_col0,#T_dbc88_row35_col0,#T_dbc88_row36_col0,#T_dbc88_row37_col0,#T_dbc88_row38_col0,#T_dbc88_row39_col0,#T_dbc88_row40_col0,#T_dbc88_row41_col0,#T_dbc88_row42_col0,#T_dbc88_row43_col0,#T_dbc88_row44_col0,#T_dbc88_row45_col0,#T_dbc88_row46_col0,#T_dbc88_row47_col0,#T_dbc88_row48_col0,#T_dbc88_row49_col0,#T_dbc88_row50_col0,#T_dbc88_row51_col0,#T_dbc88_row52_col0,#T_dbc88_row53_col0,#T_dbc88_row54_col0,#T_dbc88_row55_col0,#T_dbc88_row56_col0,#T_dbc88_row57_col0,#T_dbc88_row58_col0,#T_dbc88_row59_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_dbc88_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Incumplimiento</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dbc88_level0_row0" class="row_heading level0 row0" >Incumplimiento</th>
#                         <td id="T_dbc88_row0_col0" class="data row0 col0" >1.00000</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row1" class="row_heading level0 row1" >valor_prestamo_x_autocontrol</th>
#                         <td id="T_dbc88_row1_col0" class="data row1 col0" >0.00626</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row2" class="row_heading level0 row2" >cuentas_otros_x_tiempo_empleo</th>
#                         <td id="T_dbc88_row2_col0" class="data row2 col0" >0.00613</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row3" class="row_heading level0 row3" >autocontrol_x_confianza</th>
#                         <td id="T_dbc88_row3_col0" class="data row3 col0" >0.00571</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row4" class="row_heading level0 row4" >saldo_cuenta_x_impulsividad</th>
#                         <td id="T_dbc88_row4_col0" class="data row4 col0" >0.00557</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row5" class="row_heading level0 row5" >Cuentas_otros</th>
#                         <td id="T_dbc88_row5_col0" class="data row5 col0" >0.00547</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row6" class="row_heading level0 row6" >autocontrol_x_impulsividad</th>
#                         <td id="T_dbc88_row6_col0" class="data row6 col0" >0.00544</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row7" class="row_heading level0 row7" >saldo_cuenta_x_autocontrol</th>
#                         <td id="T_dbc88_row7_col0" class="data row7 col0" >0.00542</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row8" class="row_heading level0 row8" >cuentas_otros_x_autocontrol</th>
#                         <td id="T_dbc88_row8_col0" class="data row8 col0" >0.00541</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row9" class="row_heading level0 row9" >cuentas_otros_x_impulsividad</th>
#                         <td id="T_dbc88_row9_col0" class="data row9 col0" >0.00540</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row10" class="row_heading level0 row10" >saldo_cuenta_x_confianza</th>
#                         <td id="T_dbc88_row10_col0" class="data row10 col0" >0.00536</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row11" class="row_heading level0 row11" >valor_prestamo_x_saldo_cuenta</th>
#                         <td id="T_dbc88_row11_col0" class="data row11 col0" >0.00524</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row12" class="row_heading level0 row12" >Saldo_cuenta</th>
#                         <td id="T_dbc88_row12_col0" class="data row12 col0" >0.00523</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row13" class="row_heading level0 row13" >cuentas_otros_x_confianza</th>
#                         <td id="T_dbc88_row13_col0" class="data row13 col0" >0.00511</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row14" class="row_heading level0 row14" >cuentas_otros_x_autocontrol_entre_tiempo_empleo</th>
#                         <td id="T_dbc88_row14_col0" class="data row14 col0" >0.00456</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row15" class="row_heading level0 row15" >cuentas_otros_x_confianza_entre_tiempo_empleo</th>
#                         <td id="T_dbc88_row15_col0" class="data row15 col0" >0.00453</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row16" class="row_heading level0 row16" >tiempo_empleo_x_autocontrol_entre_cuentas_otros</th>
#                         <td id="T_dbc88_row16_col0" class="data row16 col0" >0.00452</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row17" class="row_heading level0 row17" >Autocontrol</th>
#                         <td id="T_dbc88_row17_col0" class="data row17 col0" >0.00449</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row18" class="row_heading level0 row18" >cuentas_otros_x_valor_prestamo</th>
#                         <td id="T_dbc88_row18_col0" class="data row18 col0" >0.00447</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row19" class="row_heading level0 row19" >Valor_prestamo</th>
#                         <td id="T_dbc88_row19_col0" class="data row19 col0" >0.00444</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row20" class="row_heading level0 row20" >tiempo_empleo_x_confianza_entre_cuentas_otros</th>
#                         <td id="T_dbc88_row20_col0" class="data row20 col0" >0.00434</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row21" class="row_heading level0 row21" >cuentas_otros_x_valor_prestamo_entre_tiempo_empleo</th>
#                         <td id="T_dbc88_row21_col0" class="data row21 col0" >0.00426</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row22" class="row_heading level0 row22" >valor_prestamo_x_impulsividad</th>
#                         <td id="T_dbc88_row22_col0" class="data row22 col0" >0.00414</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row23" class="row_heading level0 row23" >saldo_cuenta_x_tiempo_empleo_entre_cuentas_otros</th>
#                         <td id="T_dbc88_row23_col0" class="data row23 col0" >0.00411</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row24" class="row_heading level0 row24" >cuentas_otros_x_impulsividad_entre_tiempo_empleo</th>
#                         <td id="T_dbc88_row24_col0" class="data row24 col0" >0.00410</td>
#             </tr>
#             <tr>
#                         <th id="T_dbc88_level0_row25" class="row_heading level0 row25" >tiempo_empleo_x_impulsividad_entre_cuentas_otros</th>
#                         <td id=

# %% [markdown]
# ## ESCALAMIENTO

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X_train = train.drop(['id', 'Incumplimiento'], axis=1)
columnas_train = X_train.columns
X_test = test.drop(['id', 'Incumplimiento'], axis=1)
columnas_test = X_test.columns

all(columnas_train == columnas_test)
# Out:
# True

# %%
assert all(columnas_train == columnas_test)

# %%
#scaler = MinMaxScaler()
#X_train = scaler.fit_transform(X_train)

# %%
import joblib

#joblib.dump(scaler, 'scaler.pkl')
#load_scaler = joblib.load('scaler.pkl')    #--> para cargarlo en un ambiente externo

#X_test = load_scaler.transform(X_test)

# %%
#X_train = pd.DataFrame(X_train, columns=columnas_train)
#X_test = pd.DataFrame(X_test, columns=columnas_test)

# %%
#X_train.corr(method='spearman').style.background_gradient(
#    cmap='coolwarm', axis=None
#).set_precision(5)

# %%
#X_test.corr(method='spearman').style.background_gradient(
#    cmap='coolwarm', axis=None
#).set_precision(5)

# %% [markdown]
# ### Separacion en TRAIN Y VALIDACION

# %%
X_test.head()
# Out:
#    Empleado  Tiempo_empleo  Saldo_cuenta  Valor_prestamo  Cuentas_otros  Autocontrol  Impulsividad  Confianza  cuentas_otros_x_valor_prestamo  cuentas_otros_x_valor_prestamo_entre_tiempo_empleo  cuentas_otros_x_saldo_cuenta  cuentas_otros_x_saldo_cuenta_entre_tiempo_empleo  cuentas_otros_x_tiempo_empleo  cuentas_otros_x_autocontrol  cuentas_otros_x_autocontrol_entre_tiempo_empleo  cuentas_otros_x_impulsividad  cuentas_otros_x_impulsividad_entre_tiempo_empleo  cuentas_otros_x_confianza  cuentas_otros_x_confianza_entre_tiempo_empleo  valor_prestamo_x_saldo_cuenta  valor_prestamo_x_saldo_cuenta_entre_cuentas_otros  valor_prestamo_x_saldo_cuenta_entre_tiempo_empleo  valor_prestamo_x_tiempo_empleo  valor_prestamo_x_tiempo_empleo_entre_cuentas_otros  valor_prestamo_x_autocontrol  valor_prestamo_x_autocontrol_entre_cuentas_otros  valor_prestamo_x_autocontrol_entre_tiempo_empleo  valor_prestamo_x_impulsividad  valor_prestamo_x_impulsividad_entre_cuentas_otros  \
# 0         1              9       285.541           0.000              1           50            61         53                           0.000                                           0.000000                        285.541                                         31.726778                              9                           50                                         5.555556                            61                                          6.777778                         53                                       5.888889                   0.000000e+00                                           0.000000                                           0.000000                           0.000                                             0.0000                          0.000                                             0.000                                          0.000000                          0.000                                             0.0000
# 1         1              3       327.126        3226.726              2           47            65         56                        6453.452                                        2151.150667                        654.252                                        218.084000                              6                           94                                        31.333333                           130                                         43.333333                        112                                      37.333333                   1.055546e+06                                      527772.984738                                      351848.656492                        9680.178                                          4840.0890                     151656.122                                         75828.061                                      50552.040667                     209737.190                                        104868.5950
# 2         1              2       287.253        2774.996              1           68            59         63                        2774.996                                        1387.498000                        287.253                                        143.626500                              2                           68                                        34.000000                            59                                         29.500000                         63                                      31.500000                   7.971259e+05                                      797125.925988                                      398562.962994                        5549.992                                          5549.9920                     188699.728                                        188699.728                                      94349.864000                     163724.764                                        163724.7640
# 3         0              0       257.328        2757.177              1           59            49         47                        2757.177                                           0.000000                        257.328                                          0.000000                              0                           59                                         0.000000                            49                                          0.000000                         47                                       0.000000                   7.094988e+05                                      709498.843056                                           0.000000                           0.000                                             0.0000                     162673.443                                        162673.443                                          0.000000                     135101.673                                        135101.6730
# 4         1              1       235.422        1923.073              2           66            45         36                        3846.146                                        3846.146000                        470.844                                        470.844000                              2                          132                                       132.000000                            90                                         90.000000                         72                                      72.000000                   4.527337e+05                                      226366.845903                                      452733.691806                        1923.073                                           961.5365                     126922.818                                         63461.409                                     126922.818000                      86538.285                                         43269.1425
#
#    valor_prestamo_x_impulsividad_entre_tiempo_empleo  valor_prestamo_x_confianza  valor_prestamo_x_confianza_entre_cuentas_otros  valor_prestamo_x_confianza_entre_tiempo_empleo  saldo_cuenta_x_tiempo_empleo  saldo_cuenta_x_tiempo_empleo_entre_cuentas_otros  saldo_cuenta_x_autocontrol  saldo_cuenta_x_autocontrol_entre_cuentas_otros  saldo_cuenta_x_autocontrol_entre_tiempo_empleo  saldo_cuenta_x_impulsividad  saldo_cuenta_x_impulsividad_entre_cuentas_otros  saldo_cuenta_x_impulsividad_entre_tiempo_empleo  saldo_cuenta_x_confianza  saldo_cuenta_x_confianza_entre_cuentas_otros  saldo_cuenta_x_confianza_entre_tiempo_empleo  tiempo_empleo_x_autocontrol  tiempo_empleo_x_autocontrol_entre_cuentas_otros  tiempo_empleo_x_impulsividad  tiempo_empleo_x_impulsividad_entre_cuentas_otros  tiempo_empleo_x_confianza  tiempo_empleo_x_confianza_entre_cuentas_otros  autocontrol_x_impulsividad  autocontrol_x_impulsividad_entre_cuentas_otros  autocontrol_x_impulsividad_entre_tiempo_empleo  \
leo  valor_prestamo_x_saldo_cuenta  valor_prestamo_x_saldo_cuenta_entre_cuentas_otros  valor_prestamo_x_saldo_cuenta_entre_tiempo_empleo  valor_prestamo_x_tiempo_empleo  valor_prestamo_x_tiempo_empleo_entre_cuentas_otros  valor_prestamo_x_autocontrol  valor_prestamo_x_autocontrol_entre_cuentas_otros  valor_prestamo_x_autocontrol_entre_tiempo_empleo  valor_prestamo_x_impulsividad  valor_prestamo_x_impulsividad_entre_cuentas_otros  \
# 0         0              0       128.133        2895.710              1           45            50         74                        2895.710                                           0.000000                        128.133                                          0.000000                              0                           45                                         0.000000                            50                                          0.000000                         74                                       0.000000                   3.710360e+05                                       3.710360e+05                                       0.000000e+00                           0.000                                              0.000                     130306.950                                        130306.950                                          0.000000                     144785.500                                         144785.500
# 1         1              9       919.644        2781.780              0           38            49         58                           0.000                                           0.000000                          0.000                                          0.000000                              0                            0                                         0.000000                             0                                          0.000000                          0                                       0.000000                   2.558247e+06                                       0.000000e+00                                       2.842497e+05                       25036.020                                              0.000                     105707.640                                             0.000                                      11745.293333                     136307.220                                              0.000
# 2         1              4      1521.332        4216.502              1           59            54         37                        4216.502                                        1054.125500                       1521.332                                        380.333000                              4                           59                                        14.750000                            54                                         13.500000                         37                                       9.250000                   6.414699e+06                                       6.414699e+06                                       1.603675e+06                       16866.008                                          16866.008                     248773.618                                        248773.618                                      62193.404500                     227691.108                                         227691.108
# 3         0              0       172.603        1782.369              0           57            58         54                           0.000                                           0.000000                          0.000                                          0.000000                              0                            0                                         0.000000                             0                                          0.000000                          0                                       0.000000                   3.076422e+05                                       0.000000e+00                                       0.000000e+00                           0.000                                              0.000                     101595.033                                             0.000                                          0.000000                     103377.402                                              0.000
# 4         1              9       170.364        3918.458              1           49            37         37                        3918.458                                         435.384222                        170.364                                         18.929333                              9                           49                                         5.444444                            37                                          4.111111                         37                                       4.111111                   6.675642e+05                                       6.675642e+05                                       7.417380e+04                       35266.122                                          35266.122                     192004.442                                        192004.442                                      21333.826889                     144982.946                                         144982.946
#
#    valor_prestamo_x_impulsividad_entre_tiempo_empleo  valor_prestamo_x_confianza  valor_prestamo_x_confianza_entre_cuentas_otros  valor_prestamo_x_confianza_entre_tiempo_empleo  saldo_cuenta_x_tiempo_empleo  saldo_cuenta_x_tiempo_empleo_entre_cuentas_otros  saldo_cuenta_x_autocontrol  saldo_cuenta_x_autocontrol_entre_cuentas_otros  saldo_cuenta_x_autocontrol_entre_tiempo_empleo  saldo_cuenta_x_impulsividad  saldo_cuenta_x_impulsividad_entre_cuentas_otros  saldo_cuenta_x_impulsividad_entre_tiempo_empleo  saldo_cuenta_x_confianza  saldo_cuenta_x_confianza_entre_cuentas_otros  saldo_cuenta_x_confianza_entre_tiempo_empleo  tiempo_empleo_x_autocontrol  tiempo_empleo_x_autocontrol_entre_cuentas_otros  tiempo_empleo_x_impulsividad  tiempo_empleo_x_impulsividad_entre_cuentas_otros  tiempo_empleo_x_confianza  tiempo_empleo_x_confianza_entre_cuentas_otros  autocontrol_x_impulsividad  autocontrol_x_impulsividad_entre_cuentas_otros  autocontrol_x_impulsividad_entre_tiempo_empleo  \
# 0                                           0.000000                  214282.540                                      214282.540                                        0.000000                         0.000                                             0.000                    5765.985                                        5765.985                                        0.000000                     6406.650                                         6406.650                                         0.000000                  9481.842                                      9481.842                                      0.000000                            0                                              0.0                             0                                               0.0                          0                                            0.0                        2250                                          2250.0                                        0.000000
# 1                                       15145.246667                  161343.240                                           0.000                                    17927.026667                      8276.796                                             0.000                   34946.472                                           0.000                                     3882.941333                    45062.556                                            0.000                                      5006.950667                 53339.352                                         0.000                                   5926.594667                          342                                              0.0                           441                                               0.0                        522                                            0.0                        1862                                             0.0                                      206.888889
# 2                                       56922.777000                  156010.574                                      156010.574                                    39002.643500                      6085.328                                          6085.328                   89758.588                                       89758.588                                    22439.647000                    82151.928                                        82151.928                                     20537.982000                 56289.284                                     56289.284                                  14072.321000                          236                                            236.0                           216                                             216.0                        148                                          148.0                        3186                                          3186.0                                      796.500000
# 3                                           0.000000                   96247.926                                           0.000                                        0.000000                         0.000                                             0.000                    9838.371                                           0.000                                        0.000000                    10010.974                                            0.000                                         0.000000                  9320.562                                         0.000                                      0.000000                            0                                              0.0                             0                                               0.0                          0                                            0.0                        3306                                             0.0                                        0.000000
# 4                                       16109.216222                  144982.946                                      144982.946                                    16109.216222                      1533.276                                          1533.276                    8347.836                                        8347.836                                      927.537333                     6303.468                                         6303.468                                       700.385333                  6303.468                                      6303.468                                    700.385333                          441                                            441.0                           333                                             333.0                        333                                          333.0                        1813                                          1813.0                                      201.444444
#
#    autocontrol_x_confianza  autocontrol_x_confianza_entre_cuentas_otros  autocontrol_x_confianza_entre_tiempo_empleo  impulsividad_x_confianza  impulsividad_x_confianza_entre_cuentas_otros  impulsividad_x_confianza_entre_tiempo_empleo
# 0                     3330                                       3330.0                                     0.000000                      3700                                        3700.0                                      0.000000
# 1                     2204                                          0.0                                   244.888889                      2842                                           0.0                                    315.777778
# 2                     2183                                       2183.0                                   545.750000                      1998                                        1998.0                                    499.500000
# 3                     3078                                          0.0                                     0.000000                      3132                                           0.0                                      0.000000
# 4                     1813                                       1813.0                                   201.444444                      1369                                        1369.0                                    152.111111

# %%
X_train.shape, X_test.shape
# Out:
# ((63901, 59), (16116, 59))

# %%
y_train = train['Incumplimiento'].copy()
del train
del test

# %%
y_train.shape
# Out:
# (63901,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.85, random_state=SEED, stratify=y_train)

# %%
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((54315, 59), (9586, 59), (54315,), (9586,))

# %% [markdown]
# ### SAVE

# %%
X_train.to_csv('X_train.csv', index=False)
X_valid.to_csv('X_valid.csv', index=False)
X_test.to_csv('X_test.csv', index=False)

# %%
y_train.to_csv('y_train.csv', index=False)
y_valid.to_csv('y_valid.csv', index=False)

# %%
X_train['Imcumplimiento'] = y_train
X_valid['Imcumplimiento'] = y_valid
X_train.to_csv('X_train_r.csv', index=False)
X_valid.to_csv('X_valid_r.csv', index=False)

# %% [markdown]
# ### Información de versionaiento

# %%
# !pip install sinfo

# %%
from sinfo import sinfo
sinfo()
